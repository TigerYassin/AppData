# %% [markdown]
# ## setting up variables

# %%
import pandas as pd

text_path = 'AppleStore.csv'
df = pd.read_csv(text_path)
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df.sort_values('rating_count_ver', ascending=False).head()
# Out:
#       Unnamed: 0          id                                      track_name  \
# 498          568   387428400                                  Infinity Blade
# 4467        5666  1045901853                          Geometry Dash Meltdown
# 690          791   416023011                                      My Verizon
# 1780        2070   597855590                                 Real Basketball
# 127          142   310738695  Zillow Real Estate - Homes for Sale & for Rent
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 498    624107810      USD   0.99            326482            177050
# 4467    55445504      USD   0.00            117470            117470
# 690    150791168      USD   0.00            126948            107245
# 1780    70336512      USD   0.00            198050             94315
# 127    132632576      USD   0.00            342969             88478
#
#       user_rating  user_rating_ver     ver cont_rating prime_genre  \
# ...

# %%
groups = df.groupby("prime_genre") #returns a groupby Dataframe
# how to iterate through the groupby dataframe 
'''
for g1, g2 in groups:   
    print(g1)
    print(g2)
'''

lifestyle = groups.get_group("Lifestyle") #another way to access groups in the dataframe 
lifestyle.head() #will only output apps from "lifestyle"
# Out:
#      Unnamed: 0         id                                      track_name  \
# 54           63  295759189                       Big Day - Event Countdown
# 55           64  295775656    12 Steps AA Companion - Alcoholics Anonymous
# 127         142  310738695  Zillow Real Estate - Homes for Sale & for Rent
# 217         247  333206289                        Alipay - Makes Life Easy
# 219         249  333263435                                 Daily Teachings
#
#      size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 54     13156352      USD   0.99               812                14
# 55     30367744      USD   2.99              1583                 2
# 127   132632576      USD   0.00            342969             88478
# 217   208309248      USD   0.00              1926                 2
# 219    20298752      USD   4.99              1340               288
#
#      user_rating  user_rating_ver      ver cont_rating prime_genre  \
# ...

# %% [markdown]
# ## Showing the names of the groups created

# %%
list(groups.groups) #shows us all the app categories 
groups.groups.keys() #another way to do it
# Out:
# ['Productivity',
#  'Photo & Video',
#  'Entertainment',
#  'Travel',
#  'Sports',
#  'Food & Drink',
#  'Book',
#  'Music',
#  'Shopping',
#  'Catalogs',
#  'Finance',
#  'Business',
#  'Navigation',
#  'Utilities',
#  'News',
#  'Lifestyle',
#  'Medical',
#  'Games',
#  'Health & Fitness',
#  'Social Networking',
#  'Reference',
#  'Weather',
#  'Education']

# %% [markdown]
# ## Sorting it according to rating_count_tot

# %%
# df.set_index('prime_genre', inplace=True) 
df2 = df.sort_values("rating_count_tot", ascending=False)

group2 = df2.groupby('prime_genre')
games = group2.get_group("Games")
games.head()
# Out:
#       Unnamed: 0         id        track_name  size_bytes currency  price  \
# 1346        1561  529479190    Clash of Clans   116476928      USD    0.0
# 707          810  420009108        Temple Run    65921024      USD    0.0
# 1493        1731  553834731  Candy Crush Saga   222846976      USD    0.0
# 275          310  343200656       Angry Birds   175966208      USD    0.0
# 1246        1450  512939461    Subway Surfers   156038144      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 1346           2130805               579          4.5              4.5
# 707            1724546              3842          4.5              4.0
# 1493            961794              2453          4.5              4.5
# 275             824451               107          4.5              3.0
# 1246            706110                97          4.5              4.0
#
#           ver cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  \
# ...

# %% [markdown]
# ## Setting the index of the whole DF to prime_genre

# %%
#df.set_index('prime_genre', inplace=True)   #run this code only once and sets the prime_genre as the main index
#df.reset_index(inplace=True) #sets the index back to default 
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
lf = df.loc["Lifestyle", ['rating_count_tot', 'user_rating_ver']] #another way of creating the group without using groupby
lf.reset_index(inplace=True)
lf.describe()
# lf['rating_count_tot'].idxmax()
