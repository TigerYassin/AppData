# %%
print("working");
# Out:
# working

# %%
import pandas as pd

text_path = 'AppleStore.csv'

df = pd.read_csv(text_path)
# df

# %%
df.sort_values('rating_count_ver', ascending=False)
# Out:
#       Unnamed: 0          id  \
# 498          568   387428400
# 4467        5666  1045901853
# 690          791   416023011
# 1780        2070   597855590
# 127          142   310738695
# 125          140   310633997
# 1182        1378   500116670
# 154          176   318592730
# 1361        1577   531184261
# 545          619   392988420
# 1465        1698   548580856
# 254          288   338057689
# 4593        5863  1052231801
# 479          547   383298204
# 5346        7137  1080487957
# 2937        3505   912536422
# 3616        4405   979401801
# 3031        3623   923268741
# 369          415   364252504
# 6222        8885  1118431695
# 1615        1874   572534490
# 1809        2101   603527166
# 2989        3571   918054748
# 3296        3971   951364656
# 6688        9875  1141762073
# 1429        1654   543186831
# 4965        6483  1067589627
# 3184        3827   941143328
# 6462        9399  1130829481
# 384          434   366247306
# ...          ...         ...
# ...

# %%
groups = df.groupby("prime_genre")
groups

lifestyle = groups.get_group("Lifestyle")
groups.min()

# how to iterate through a groupby dataframe 
'''
for g1, g2 in groups:   
    print(g1)
    print(g2)
'''
# Out:
#   File "<ipython-input-29-3848810717bb>", line 8
#     *for(g1,, g2, in, groups:)
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Setting the index

# %%
# df.set_index('prime_genre', inplace=True)   #run this code only once and sets the prime_genre as the main index
#df.reset_index(inplace=True) #sets the index back to default

# %%
df.loc["Lifestyle", ['rating_count_tot', 'user_rating_ver']]
